# %% [markdown]
# 500 extra rows added to the end

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.genfromtxt("d:/Rep 1.csv", delimiter=',', skip_header=1)
pt = data[:, 0]
actual_pt = data[:, 1]
pos = data[:, 2]
tor = data[:, 3]
vel = data[:, 4]
acc = data[:, 5]
mg = data[:, 6]
vl = data[:, 7]
mmg = data[:, 8]
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
t_line, =ax1.plot(pt, tor, color='red')
a_line, =ax2.plot(pt, pos, color='green')
ax1.legend([t_line, a_line], ['Torque', 'Angle'])
# Adding legend
#ax1.legend(loc=0)
#ax2.legend(loc=0)

# adding grid
ax1.grid()

# Adding labels
ax1.set_xlabel("Time (ms)")
ax1.set_ylabel(r"Torque (Nm)")
ax2.set_ylabel(r"Angle (d)")

# Setting Y limits
#ax1.set_ylim(0, 35)
#ax2.set_ylim(-20, 100)
plt.show()

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ac_line, = ax1.plot(pt, acc, color='yellow')
v_line, = ax2.plot(pt, vel, color='blue')
ax1.legend([ac_line, v_line], ['Acceleration', 'Velocity'], loc='lower left')
ax1.grid()

# Adding labels
ax1.set_xlabel("Time (ms)")
ax1.set_ylabel("Acceleration (d/s/s)")
ax2.set_ylabel("Velocity (d/s)")
plt.show()

# %%
plt.plot(pos, tor)
plt.grid()
plt.xlabel("Angle (d)")
plt.ylabel("Torque (Nm)")
plt.show()
